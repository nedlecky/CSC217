# %% [markdown]
# <a href="https://colab.research.google.com/github/nedlecky/CSC217/blob/main/EppDM5e_05_01%2002%20Example%20Slide%2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 10

num = 1
den = n
while num < n + 2:
  print (num, den, num/den)
  
  num += 1
  den += 1
# Out:
# 1 10 0.1
# 2 11 0.18181818181818182
# 3 12 0.25
# 4 13 0.3076923076923077
# 5 14 0.35714285714285715
# 6 15 0.4
# 7 16 0.4375
# 8 17 0.47058823529411764
# 9 18 0.5
# 10 19 0.5263157894736842
# 11 20 0.55

# %%
n = 100000

num = 1
den = n
while num < n + 2:
  if num%100==0:
    print (num, den, num/den)
  
  num += 1
  den += 1
# Out:
# 100 100099 0.0009990109791306607
# 200 100199 0.0019960279044701043
# 300 100299 0.0029910567403463643
# 400 100399 0.003984103427324973
# 500 100499 0.004975173882327187
# 600 100599 0.005964273998747502
# 700 100699 0.006951409646570472
# 800 100799 0.00793658667248683
# 900 100899 0.00891981090000892
# 1000 100999 0.009901088129585442
# 1100 101099 0.010880424138715516
# 1200 101199 0.011857824682062076
# 1300 101299 0.012833295491564577
# 1400 101399 0.013806842276551051
# 1500 101499 0.014778470723849496
# 1600 101599 0.0157481864978986
# 1700 101699 0.016715995240857824
# 1800 101799 0.017681902572716825
# 1900 101899 0.018645914091404234
# 2000 101999 0.019608035372895814
# 2100 102099 0.020568271971321953
# 2200 102199 0.02152662941907455
# 2300 102299 0.022483113226913265
# 2400 102399 0.023437728884071134
# 2500 102499 0.024390481858359594
# 2600 102599 0.02534137759627287
# 2700 102699 0.026290421523091755
# 2800 102799 0.0272376190429868
# ...
