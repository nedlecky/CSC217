# %%
a={1,2,4,4,5}
print(a)
# Out:
# {1, 2, 4, 5}

# %%
b={5,1,4,2}
print(b)
# Out:
# {1, 2, 4, 5}

# %%
a==b
# Out:
# True

# %%
a[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f75b6be7d8e3> in <module>
# ----> 1 a[3]
#
# TypeError: 'set' object is not subscriptable

# %%
a=[0,-2,-1,0,1,2]
print(a)
# Out:
# [0, -2, -1, 0, 1, 2]

# %%
print(a)
print(a[1:6])
# Out:
# [0, -2, -1, 0, 1, 2]
# [-2, -1, 0, 1, 2]

# %%
print(sum(a[1:6]))
print(sum(a[2:3]))
print(sum(a[1:3]))
# Out:
# 0
# -1
# -3

# %%
print(range(3))
print(tuple(range(3)))
# Out:
# range(0, 3)
# (0, 1, 2)

# %%
at=(1,2,5,6)
print(at)
# Out:
# (1, 2, 5, 6)

# %%
at[1]=3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-83cdb571805e> in <module>
# ----> 1 at[1]=3
#
# TypeError: 'tuple' object does not support item assignment

# %%
sum=0
for i in range(1,6):
  sum += a[i]
print(sum)


sum=0
for i in range(2,3):
  sum += a[i]
print(sum)

sum=0
for i in range(1,3):
  sum += a[i]
print(sum)
# Out:
# 0
# -1
# -3
